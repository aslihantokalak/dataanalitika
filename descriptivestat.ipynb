# %%
 #Homework Tasks for Descriptive Statistics

#1.Soru- Veri setindeki mod,medyan ve ortalama 
import statistics as stats
import numpy as np
import pandas as pd

data = [21, 23, 19, 25, 30, 21, 20, 19, 25, 23]
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)
mean, median, mode

#2. Soru
import statistics as stats
import numpy as np 
import pandas as pd
data = [2, 3, 1, 4, 2, 3, 3, 2, 1, 4, 5, 3, 2, 1, 4]
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)
mean, median, mode

#3. Soru
import statistics as stats
import numpy as np 
import pandas as pd
data= [35, 40, 45, 50, 40, 35, 100, 45, 40, 35]
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)
mean, median, mode

#Homework: Measures of Dispersion

#1. Soru

import statistics as stats
import numpy as np 
import pandas as pd
data= [5, 10, 10, 10, 15, 20, 25, 25, 30]
variance = np.var(data, ddof=1)  # Sample variance
std_dev = np.std(data, ddof=1)  # Sample standard deviation
variance, std_dev

#2. Soru

import statistics as stats
import numpy as np 
import pandas as pd
data= [500, 700, 800, 600, 1200, 1000, 950, 1100]
variance = np.var(data, ddof=1)  # Sample variance
std_dev = np.std(data, ddof=1)  # Sample standard deviation
variance, std_dev

#3. Soru

import statistics as stats
import numpy as np 
import pandas as pd
data= [60, 65, 70, 75, 80, 85, 90, 95, 100]
variance = np.var(data, ddof=1)  # Sample variance
std_dev = np.std(data, ddof=1)  # Sample standard deviation
variance, std_dev

#Homework: Five Number Summary

#1. Soru

import statistics as stats
import numpy as np 
import pandas as pd
data= [100, 102, 105, 107, 110, 113, 115, 117, 120]

min_val = np.min(data)
q1 = np.percentile(data, 25)
q2 = np.percentile(data, 50)
q3 = np.percentile(data, 75)
max_val = np.max(data)
min_val, q1, q2, q3, max_val

#2. Soru    

import statistics as stats
import numpy as np 
import pandas as pd
data= [230, 250, 270, 290, 310, 330, 350, 370, 390, 410]

min_val = np.min(data)
q1 = np.percentile(data, 25)
q2 = np.percentile(data, 50)
q3 = np.percentile(data, 75)
max_val = np.max(data)
min_val, q1, q2, q3, max_val

#3. Soru

import statistics as stats
import numpy as np 
import pandas as pd
data= [35, 36, 38, 40, 42, 44, 46, 48, 50, 55]
min_val = np.min(data)
q1 = np.percentile(data, 25)
q2 = np.percentile(data, 50)
q3 = np.percentile(data, 75)
max_val = np.max(data)
min_val, q1, q2, q3, max_val
# Out:
# (np.int64(35),
#  np.float64(38.5),
#  np.float64(43.0),
#  np.float64(47.5),
#  np.int64(55))
